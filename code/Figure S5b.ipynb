# %%
# Loading graphic handler and libraries
import sys
sys.path.append('../tools')
from getFigure05 import getFigure
from plotly.offline import init_notebook_mode
#import plotly.graph_objs as go
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# <center><h2>Instructions for Figure</h2></center>
# <br>
# - Move your cursor to see the exact value of the stress on the fault surface

# %%
slipDist = 'bulls-eye' # k-square bulls-eye, uniform
friction = '0.4' # 0.3, 0.4, 0.5
fig = getFigure(slipDist, friction)
fig.show()
# Out:
# <div>                            <div id="f24260d7-77ad-4ed8-bf9f-f973489163eb" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f24260d7-77ad-4ed8-bf9f-f973489163eb")) {                    Plotly.newPlot(                        "f24260d7-77ad-4ed8-bf9f-f973489163eb",                        [{"colorbar": {"len": 0.35, "title": {"text": "Pre-Coulomb<br>stress<br>(MPa)"}, "x": 1, "y": 0.85}, "colorscale": [[0.0, "rgb(5,48,97)"], [0.1, "rgb(33,102,172)"], [0.2, "rgb(67,147,195)"], [0.3, "rgb(146,197,222)"], [0.4, "rgb(209,229,240)"], [0.5, "rgb(247,247,247)"], [0.6, "rgb(253,219,199)"], [0.7, "rgb(244,165,130)"], [0.8, "rgb(214,96,77)"], [0.9, "rgb(178,24,43)"], [1.0, "rgb(103,0,31)"]], "hovertemplate": "%{z:.2f} MPa", "name": "CBNBF-II", "showscale": f
# ...

# %% [markdown]
# <center><b>Figure 5b: </b>Pre-Coulomb stress, cummulative Coulomb stress change and rate of Coulomb stress change on the faults. First pane indicates the pre-Coulomb stress by slip deficit,second pane represents the cummulative Coulomb stress change and third pane indicates the rate of stress change.Stress calculation based on the <b>bulls-eye</b> slip distribution geometry.
# <br>
# <br>
# <b>CBEEF: </b>Central Basin Eastern Edge Fault, <b>CBIF: </b>Central Basin Inner Faults, <b>CBNBF: </b>Central Basin Northern Border Faults, <b>KBIF: </b>Kumburgaz Basin Inner Faults, <b>KBNBF: </b>Kumburgaz Basin Northern Boundary Fault, <b>NAFZ-C</b> and <b>NAFZ-D: </b>North Anatolian Fault Zone C and D segments, <b>SF: </b>Silivri Fault, <b>SRF: </b>Silivri Ridge Fault, <b>SRSBF: </b>Silivri Ridge Southern Border Fault<br></center>
